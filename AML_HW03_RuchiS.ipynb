# %% [markdown]
# #### This notebook is created as submission for Assignment 02, Advanced Machine Learning
# Submitted by: Ruchi Sharma

# %% [markdown]
# ### Question 1: Tensorflow Playground
#
# In this question, you will be playing with [Tensorflow Playground](https://playground.tensorflow.org).
#
# Select "Classification" as the Problem Type. Among the four datasets shown in DATA, please select the top left dataset.
#
# Use the following settings as the DEFAULT settings for all subquestions: Learning rate = 0.03, Activation = Tanh, Regularization = None, Ratio of training to test data = 50%, Noise = 0, Batch Size = 30, input as  𝑋1  with  𝑋2 , One hidden layer with 4 neurons.
#
# a) Use the DEFAULT setting and run two experiments - one using Tanh as the activation function and one using the Linear activation function. Report the train, test losses for both at the end of 1000 epochs. What qualitative difference do you observe in the decision boundaries obtained? What do you think is the reason for this?

# %% [markdown]
# ##### Answer

# %%
# %matplotlib inline
from PIL import Image
print("Linear Activation")
Image.open("ok.png")
# Out:
# Linear Activation
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2568x1344>

# %%
print("Tanh Activation")
Image.open("bye.png")
# Out:
# Tanh Activation
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2554x1353>

# %% [markdown]
# The following can be noted from the above experiments:
# 1. Tanh Activation --> Train loss = 0.010; Test Loss = 0.022
# 2. Linear Activation --> Train loss = 0.499; Test Loss = 0.504

# %% [markdown]
# Interpretation: We observe a linear decision boundary when using a "linear" activation function while a non linear decision boundary is obtained when using the "tanh" activation function. We also see that using the "tanh" activation function gives a better decision boundary that classifies with much better accuracy compared to when a linear activation function is used. This is because of the fact that "tanh" activation function is non-linear and helps each node to better capture the non-linear distribution in our input data.

# %% [markdown]
# We will now study the effect of certain variations in the network structure or training process, keeping all other aspects the same as in the DEFAULT setting specified above, with Tanh as the activation.
#
# b) Effect of number of hidden units: Keep other settings the same as in DEFAULT, report the training loss and test loss at the end of 1000 epochs using 2 neurons and 8 neurons in the hidden layer. What do you observe in terms of the decision boundary obtained as the number of neurons increases? What do you think is the reason for this?

# %% [markdown]
# ##### Answer

# %%
print("2 neurons in hidden layer")
Image.open("ok1.png")
# Out:
# 2 neurons in hidden layer
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2579x1369>

# %%
print("8 neurons in hidden layer")
Image.open("ok2.png")
# Out:
# 8 neurons in hidden layer
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2577x1399>

# %% [markdown]
# The following can be noted from the above experiments:
# 1. 2 Neurons: Test Loss --> 0.266, Train Loss --> 0.216
# 2. 8 Neurons: Test Loss --> 0.012, Train Loss --> 0.007

# %% [markdown]
# Interpretation:
# The decision boundary obtained using a hidden layer with 8 neurons is better able to separate data points belonging to different class labels compared to the decision boundary obtained using a hidden layer with 2 neurons. This is because higher number of neurons leads to more degrees of freedom which leads to a more effective capture of the data distribution.

# %% [markdown]
# c) Effect of Learning rate and number of epochs: Keep other settings the same as in DEFAULT. For learning rate 10, 1, 0.1, 0.01 and 0.0001, report the train, test losses at the end of 100 epochs, 500 epochs and 1000 epochs respectively. What do you observe from the change of loss vs learning rate, and the change of loss vs epoch numbers? Also report your observations on the training and test loss curve (observe if you see noise for certain learning rates and reason why this is happening).

# %% [markdown]
# ##### Answer

# %%
Image.open("okok.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1421x298>

# %% [markdown]
# For high value of alpha (alpha=10), we see that the test and training losses are large (>0.5). This indicates we are not able to achieve a minimum indicating oscillations. Also, the training and test loss curves are not smooth and spikes are observed for low epochs.
#
# For learning rates alpha =1 and 0.1, we reach the minimum fairly quickly (even before 100 epochs) indicating quick convergence. For learning rates alpha =0.01, speed of descent is slower but it reaches the minimum at epoch 1000. For learning rates alpha =0.0001, the rate of learning is very slow and it doesn't reach the minimum even at epoch 1000.
#
# The training and test loss curves for all learning rates other than 10 are observed to be smooth.

# %% [markdown]
# d) Effect of the number of layers: Change your activation to ReLU and use a single hidden layer with 4 neurons and then add another hidden layer with 3 neurons and train both your models for 1000 epochs. Comments on your final models and decision boundaries and observe your training and test loss curves as well.

# %% [markdown]
# ##### Answer
#
# The training (0.001) and test losses (0.003) come out to be very low after adding this additional hidden layer. Increasing the number of hidden layers improves the accuracy in this case, but in general it depends on the complexity of the problem that you are trying to solve. The decision boundary for both the models is found to be a hexagon.

# %% [markdown]
# e) Use the DEFAULT setting. Play around with any hyperparameters, network architectures or input features (such as  sin(𝑋1),𝑋21  etc.), and report the best train and test loss you obtain (test loss should be no greater than 0.06). Attach the screenshot showing your full network, output and the parameters. Briefly justify your results, and comment on what helps/what doesn't help with lowering the loss, etc.

# %% [markdown]
# ##### Answer

# %%
Image.open("Final2.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2880x1281>

# %% [markdown]
# By setting the features at x1^2 and x2^2 with tanh activation, we achieve near zero train and test errors in about 100 epochs with just 1 neuron in the hidden layer. In case of using x1^2 and x2^2 with no hidden layer as well, the train and test error became near zero in just 200 epochs.

# %% [markdown]
# ### Question 2: t-SNE
#
# Read this [article](https://erdem.pl/2020/04/t-sne-clearly-explained) on t-SNE, a dimensionality reduction technique for visualization and explain it in your own words in one or two paragraphs.

# %% [markdown]
# #### Answer:

# %% [markdown]
# Many popular dimensionality reduction techniques (such as PCA) are based on the linear transformations within the feature spaces. But there can be cases where we need to handle non-linear dimensionality reduction. This occurs in cases when the data is not separable by a straight line. One the algorithms that deals with such non linearity is t-SNE, t-distributed Stochastic Neighbor Embedding. Furthermore, t-SNE is iterative and unlike PCA, cannot be applied to another dataset.
#
# The goal of this algorithm is to take a set of points in a high-dimensional space and find a faithful representation of those points in a lower-dimensional space, typically the 2D plane. The algorithm is non-linear and adapts to the underlying data, performing different transformations on different regions. The algorithm creates a probability distribution that represents similarities between neighbors. Further, SNE performs a binary search for the value of sigma that produces probability distribution with a fixed perplexity that is specified by the user. The article also describes the concept of "Shannon Entropy" and points out that perplexity is positively correlated with the value of mu_i.
#
# t-SNE then creates a low-dimensional space with the same number of points as in the original space, but points should be randomly spread on a new space. The goal of this algorithm is to find similar probability distribution in low-dimensional space. But here instead of using the Gaussian, we use Student t-distribution with a single degree of freedom. Students-t “falls” quickly and has a “long tail” so points won’t get squashed into a single point.
#
# To optimize the distribution, t-SNE uses the Kullback-Leibler Divergence. t-SNE performs well itself but there are some improvements that allow it to do even better (Early compression, Early exaggeration).

# %% [markdown]
# ### Question 3: PCA
#
# Explain the principle of Principal Component Analysis algorithm and in what sense is the selection of the eigenvectors to represent the data is an optimal choice.  How do you reconstruct (a noisy version of) the original data from the eigenvectors and the loadings?

# %% [markdown]
# #### Answer:

# %% [markdown]
# Principal Component Analysis (PCA) is a linear dimensionality reduction method in statistics and helps in feature selection of the dataset. But at the same time, it ensures that there is minimum information loss. It does so by creating new uncorrelated variables called the priniple components that successively maximize variance. When we go about finding the principal components that maximizes the variance in our projected data, the approach reduces to solving an eigenvalue/eigenvector of the covariance matrix problem of the mean centered data (x- E(x)) (Mathmematics is beyond the scope of this question). The eigen vectors of the  mean centered data's covariance matrix are seen be the optimal choice when it comes to maximizing the variance of our dimensionally reduced data.
#
# These eigenvectors of the covariance matrix are actually the directions of the axes that have the greatest variance (principal components) while the eigenvalues are the coefficients attached to the eigenvectors that indicate the amount of variance contained in each principal component.
#
# PCA algorithm in vector form: $ Z = XV$ where X is our original dataset, V is the Eigen vector space matrix and Z is dimentionally reduced data (loading)
#
# **Reconstruction:**
#
# If we want to get our original data back, we can multiply the loadings Z with the transpose of the eigenvector matrix - $\hat{X} = ZV^T$. This would give a noisy version of X as we lost information when we mapped it to a lower dimensional space

# %% [markdown]
# ### Question 4: Outlier detection using PyOD
#
# Outlier detection, or anomaly detection is usually an unsupervised learning task where the objective is to identify suspicious observations in data. It has been widely used in military surveillance for enemy activities to prevent attacks, intrusion detection in cyber security, fraud detection for credit cards, etc.
#
# PyOD is a comprehensive and scalable Python library for detecting outlying objects in multivariate data. PyOD includes more than 30 detection algorithms and provides unified APIs which makes it quite handy to use. In this question, you will play with PyOD, explore three different outlier detection algorithms and compare their performances. First let's install PyOD.

# %%
# install pyod using pip first
# !pip install pyod

# %%
from pyod.models.knn import KNN
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

train_df = pd.read_csv('Q3_train_dataset.csv')
test_df = pd.read_csv('Q3_test_dataset.csv')

X_train = train_df[['X_train_0', 'X_train_1', 'X_train_2', 'X_train_3', 'X_train_4']].to_numpy()
y_train = train_df[['y_train']].to_numpy()
X_test = test_df[['X_test_0', 'X_test_1', 'X_test_2', 'X_test_3', 'X_test_4']].to_numpy()
y_test = test_df[['y_test']].to_numpy()

# %%
# (a)
from pyod.models.knn import KNN
clf = KNN() # initialize KNN class using the default parameters

# fit the model using X_train
clf.fit(X_train)
y_train_pred = clf.labels_
y_train_scores = clf.decision_scores_

# %%
from pyod.utils.data import evaluate_print
# predict the outlier labels of X_test using the trained model, compute the raw outlier scores on X_test using decision_function()
# then use evaluate_print() to print out the evaluation results

y_test_pred = clf.predict(X_test)  # outlier labels (0 or 1)
y_test_scores = clf.decision_function(X_test)  # outlier scores

print("\nOn Training Data:")
evaluate_print(clf, y_train, y_train_scores)

print("\nOn Test Data:")
evaluate_print(clf, y_test, y_test_scores)
# Out:
# On Training Data:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0) ROC:0.8982, precision @ rank n:0.625
#
# On Test Data:
# KNN(algorithm='auto', contamination=0.1, leaf_size=30, method='largest',
#   metric='minkowski', metric_params=None, n_jobs=1, n_neighbors=5, p=2,
#   radius=1.0) ROC:0.9044, precision @ rank n:0.5

# %%
# (b)
from sklearn.decomposition import PCA

pca = PCA(n_components=2)

# Fit pca to X_train and X_test and transform 
train_principalComponents = pca.fit_transform(X_train)
test_principalComponents = pca.transform(X_test)

from pyod.utils.example import visualize
# Visualize the ground truth outliers and predicted outliers using visualize()

visualize(clf, train_principalComponents, y_train, test_principalComponents, 
              y_test, y_train_pred,y_test_pred, show_figure=True, save_figure=False)

# %%
# (c)
from pyod.models.inne import INNE

clf_inne = INNE()
clf_inne.fit(X_train)
y_train_pred_inne = clf_inne.labels_
y_train_scores_inne= clf_inne.decision_scores_

y_test_pred_inne= clf_inne.predict(X_test)  # outlier labels (0 or 1)
y_test_scores_inne= clf_inne.decision_function(X_test)  # outlier scores

# %%
print("\nOn Training Data:")
evaluate_print(clf_inne, y_train, y_train_scores_inne)

print("\nOn Test Data:")
evaluate_print(clf_inne, y_test, y_test_scores_inne)
# Out:
# On Training Data:
# INNE(contamination=0.1, max_samples='auto', n_estimators=200,
#    random_state=None) ROC:0.895, precision @ rank n:0.575
#
# On Test Data:
# INNE(contamination=0.1, max_samples='auto', n_estimators=200,
#    random_state=None) ROC:0.8433, precision @ rank n:0.6

# %%
visualize(clf_inne, train_principalComponents, y_train, test_principalComponents, 
          y_test, y_train_pred_inne,y_test_pred_inne, show_figure=True, save_figure=False)

# %% [markdown]
# The ROC for INNE (0.8633) is worse than the ROC (0.9044) for K-Nearest Neighbours. However, when it comes to precision, INNE (0.6) is better than KNN (0.5). This means that INNE is better than KNN at predicting "actual outliers" as "outliers" (higher precision). However in the process, it is also incorrectly predicting "non-outlier points" as "outliers" (lower ROC) when compared to KNN. This is further corroborated in the visuals we are seeing.

# %% [markdown]
# ### Question 5: Pre-processing and sampling
#
# The following dataset contains House prices describing the sales of individual residential property in Ames, Iowa data with explanatory variables describing almost every aspect of residential homes and dependent variable being SalePrice. Here, some cells of most columns in the dataset contain NaN values.

# %%
import pandas as pd 
import numpy as np 
import scipy.stats as stats
import math
import matplotlib.pyplot as plt
np.random.seed(100)

data = pd.read_csv("sales_data.csv")
data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Alley  OverallQual  OverallCond  \
# 0          60       RL         65.0     8450   NaN            7            5
# 1          20       RL         80.0     9600   NaN            6            8
# 2          60       RL         68.0    11250   NaN            7            5
# 3          70       RL         60.0     9550   NaN            7            5
# 4          60       RL         84.0    14260   NaN            8            5
#
#    YearBuilt  YearRemodAdd  MasVnrArea  ... 3SsnPorch  ScreenPorch  PoolArea  \
# 0       2003          2003       196.0  ...         0            0         0
# 1       1976          1976         0.0  ...         0            0         0
# 2       2001          2002       162.0  ...         0            0         0
# 3       1915          1970         0.0  ...         0            0         0
# 4       2000          2000       350.0  ...         0            0         0
#
# ...

# %% [markdown]
# a) Print the number of NaN, NULL and empty values (combined sum) in each column.

# %%
data.isna().sum()
# Out:
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Alley            1369
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# MasVnrArea          8
# ExterQual           0
# BsmtFinSF1          0
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageCars          0
# GarageArea          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ...

# %% [markdown]
# b) Create a copy of `data`, and name it `data_dm`, then create a new column in `data_dm` named `binned_garage_yr_built` and apply binning to the column `garage_yr_built`. Use `pandas.cut()` and modify its parameter list as below:
#
# ```
# bins=[1900, 1930, 1960, 1990, 2020]
# labels=['1900-1930', '1930-1960', '1960-1990', '1990-2020']
# include_lowest=True
# ```
# Next, perform one-hot encoding on this new column.

# %%
import copy
data_dm = data.copy()
data_dm['binned_garage_yr_built'] = pd.cut(data_dm['GarageYrBlt'], [1900, 1930, 1960, 1990, 2020], labels = ['1900-1930', '1930-1960', '1960-1990', '1990-2020'], 
               include_lowest = True)
pd.get_dummies(data_dm['binned_garage_yr_built'])
# Out:
#       1900-1930  1930-1960  1960-1990  1990-2020
# 0             0          0          0          1
# 1             0          0          1          0
# 2             0          0          0          1
# 3             0          0          0          1
# 4             0          0          0          1
# ...         ...        ...        ...        ...
# 1455          0          0          0          1
# 1456          0          0          1          0
# 1457          0          1          0          0
# 1458          0          1          0          0
# 1459          0          0          1          0
#
# [1460 rows x 4 columns]

# %% [markdown]
# c) Drop the columns which have more than 90%, 95% and 98% of missing values. List the columns which get dropped in each of the cases and observe the number of columns that get dropped in each of the cases as well.

# %%
data_90=data.apply(lambda x: x.isnull().sum()/len(data)>0.90)
data_90[data_90]
# Out:
# Alley          True
# PoolQC         True
# MiscFeature    True
# dtype: bool

# %%
data_95=data.apply(lambda x: x.isnull().sum()/len(data)>0.95)
data_95[data_95]
# Out:
# PoolQC         True
# MiscFeature    True
# dtype: bool

# %%
data_98=data.apply(lambda x: x.isnull().sum()/len(data)>0.98)
data_98[data_98]
# Out:
# PoolQC    True
# dtype: bool

# %%
data.columns
# before dropping columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Alley',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea',
#        'ExterQual', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'PoolQC',
#        'Fence', 'MiscFeature', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
perc = 90.0 
min_count =  int(((100-perc)/100)*data.shape[0] + 1)
data = data.dropna(axis=1, 
                thresh=min_count)

# %%
data.columns
#after dropping columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'ExterQual',
#        'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'Fence',
#        'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %% [markdown]
# d) Take a sample of 800 rows at random and compute its mean. Compare the result with the population mean.

# %%
np.random.seed(6)
sample_ages = np.random.choice(a= data['SalePrice'], size=800)
#Sample mean
print("Sample Mean:",np.mean(sample_ages))

#Population mean
print("Population Mean:",data['SalePrice'].mean())
# Out:
# Sample Mean: 178292.63125
# Population Mean: 180921.19589041095

# %% [markdown]
# e) Calculate 95% confidence intervals for SalePrice with a sample size of 100.

# %%
import scipy.stats as st

np.random.seed(10)
sample_size = 100
sample = np.random.choice(a= data_dm['SalePrice'],
                          size = sample_size)
sample_mean = sample.mean()

#Get the critical Z value
z_critical= st.norm.ppf(.975)

#Get population standard deviation
pop_stdev=data['SalePrice'].std()

#margin of error
margin_of_error = z_critical * (pop_stdev/math.sqrt(sample_size)) 

#confidence interval
confidence_interval = (sample_mean - margin_of_error,
                       sample_mean + margin_of_error)  

#Print confidence interval and true mean value
print(confidence_interval)
print("Population Mean:",data['SalePrice'].mean())
# Out:
# (166522.08555078227, 197662.97444921773)
# Population Mean: 180921.19589041095
